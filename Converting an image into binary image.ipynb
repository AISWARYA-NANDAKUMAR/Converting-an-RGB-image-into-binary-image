# %%
import matplotlib.pyplot as plt
import scipy.ndimage
from timeit import timeit
from PIL import Image
import numpy as np
import matplotlib.image as img
from PIL import Image
img = Image.open(r"C:/Users/nobody/Desktop/img/pixels.jpg") 
img1 = img.convert("L") 
img1.show() 
img2 = img.convert("1") 
img2.show() 
plt.imshow(img2)
img2=img2.save("C:/Users/nobody/Desktop/img/img2.jpg")
